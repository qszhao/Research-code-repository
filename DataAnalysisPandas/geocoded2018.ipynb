# %%
import pandas as pd

# %%
sa2018 = pd.read_excel(open('geocoded18May-Aug.xlsx','rb'))

# %%
sa2018
# Out:
#       Household.ID  Household.Size  Children TSA.Family.Type  \
# 0           153688               1         0  Woman (Single)
# 1           170452               1         0    Man (Single)
# 2           216641               1         0  Woman (Single)
# 3           275668               5         3          Family
# 4           275668               5         3          Family
# 5           275668               5         3          Family
# 6           275668               5         3          Family
# 7           275668               5         3          Family
# 8           313088               2         0          Family
# 9           313088               2         0          Family
# 10          357850               1         0    Man (Single)
# 11          367533               1         0  Woman (Single)
# 12          465074               1         0          Family
# 13          533509               4         1          Family
# ...

# %%
sa2018.describe()
# Out:
#        Household.ID  Household.Size     Children           Zip  \
# count  1.629000e+03     1629.000000  1629.000000   1629.000000
# mean   2.401271e+06        4.588091     2.430325  85035.049110
# std    8.826477e+05        2.382446     1.996210    958.245898
# min    1.536880e+05        1.000000     0.000000  48206.000000
# 25%    1.800217e+06        3.000000     1.000000  85008.000000
# 50%    2.791743e+06        4.000000     2.000000  85015.000000
# 75%    3.184046e+06        6.000000     4.000000  85035.000000
# max    3.212320e+06       14.000000     8.000000  90059.000000
#
#        Household.Income  Household.Benefits          lon          lat
# count        614.000000          348.000000  1629.000000  1629.000000
# mean        1750.891319          706.298678  -112.035969    33.485034
# std         2869.887180          628.552891     1.313196     0.256180
# min           17.000000           12.000000  -118.257419    33.038604
# ...

# %%
#sa2015.AssistanceType.value_counts()
# Out:
# Share - SRP    368
# Share - APS    272
# ACAA           115
# Share SWG       87
# Name: AssistanceType, dtype: int64

# %%
# Checking missing values
print sa2018.isnull().any()
# Out:
# Household.ID               False
# Household.Size             False
# Children                   False
# TSA.Family.Type            False
# Detailed.Family.Type       False
# Is.Chronically.Homeless    False
# Address                    False
# City                       False
# State                      False
# Zip                        False
# County                     False
# Gender                     False
# Race.Description           False
# Ethnicity                  False
# Household.Income            True
# Household.Benefits          True
# full_address               False
# lon                        False
# lat                        False
# dtype: bool
