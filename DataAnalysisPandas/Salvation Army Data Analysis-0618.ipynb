# %%
# Delete two rows without gender
# Delete out of state records


# Next step: change the categorical data to percentage (percent male and female at each zip code, female-male ratio)
# Have a count number for each zip code (use for analysis)
# average of household size, average of children number, average of age, average of household income and benefits
import pandas as pd

# %%
sa2015 = pd.read_excel(open('AssistanceDetailWithDemographics-2015-2017-analysis.xlsx','rb'), sheet_name='2015')
sa2016 = pd.read_excel(open('AssistanceDetailWithDemographics-2015-2017-analysis.xlsx','rb'), sheet_name='2016')
sa2017 = pd.read_excel(open('AssistanceDetailWithDemographics-2015-2017-analysis.xlsx','rb'), sheet_name='2017')

# %%
sa2015
# Out:
#       Household_Size  Children TSA_Family_Type  \
# 0                 10         8          Family
# 1                 10         8          Family
# 2                 10         8          Family
# 3                 10         8          Family
# 4                 10         8          Family
# 5                 10         8          Family
# 6                 10         8          Family
# 7                 10         8          Family
# 8                 10         8          Family
# 9                 10         8          Family
# 10                10         8          Family
# 11                10         8          Family
# 12                 9         3          Family
# 13                 9         3          Family
# 14                 9         3          Family
# 15                 9         3          Family
# 16                 9         3          Family
# 17                 9         3          Family
# 18                 9         3          Family
# ...

# %%
sa2015.TSA_Family_Type.unique()
# Out:
# array(['Family', 'Woman (Single)', 'Man (Single)', 'Children Only'],
#       dtype=object)

# %%
sa2015.TSA_Family_Type.value_counts()
# Out:
# Family            2470
# Woman (Single)     103
# Man (Single)        70
# Children Only        2
# Name: TSA_Family_Type, dtype: int64

# %%
sa2015.Detailed_Family_Type.value_counts()
# Out:
# Families with single adult moms               1266
# Families with two adult parents                760
# Families with no children                      248
# Families with single adult dads                128
# Single women                                   117
# Single men                                      94
# Families with one or more parents under 18      16
# Families with single moms under 18               7
# Families with single dads under 18               6
# Undefined family types                           2
# Single females under 18                          1
# Name: Detailed_Family_Type, dtype: int64

# %%
sa2015.Is_Chronically_Homeless.value_counts()
# Out:
# False    2645
# Name: Is_Chronically_Homeless, dtype: int64

# %%
sa2015.City.value_counts()
# Out:
# Phoenix             1898
# Phoenix              499
# Laveen                65
# Glendale              43
# Pheonix               18
# Mesa                  18
# Laveen                16
# Peoria                10
# Lukachuai              9
# Prescott               8
# Glendale               8
# Phoneix                6
# Prescott Valley        6
# Phownix                5
# Phoenx                 5
# Pjoenix                5
# Pheonix                4
# Phoenxi                4
# Apache Junction        4
# Globe                  3
# Phx                    3
# Scottsdale             2
# Goodyear               2
# Pgoenix                2
# Apache Junction        1
# Tempe                  1
# Name: City, dtype: int64

# %%
sa2015.State.unique()
# Out:
# array(['AZ'], dtype=object)

# %%
sa2015.County.unique()
# Out:
# array(['(No Geographic Area)', 'Coconino County', 'Gila County',
#        'Los Alamos County', 'Maricopa County', 'Maricopa County, AZ',
#        'Multnomah County, OR', 'Pinal County'], dtype=object)

# %%
# Out:
# ['M', 'F']

# %%
# -- DETAILED FAMILY TYPE --- #

# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.Zip)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.Detailed_Family_Type)))
# print(unique_second_level)

'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''

def write_df(x):
    for key,index in x.iteritems():
        _zip = key[0]
        break
    with open('2015_zip_DetailedFamilyType.csv', 'a') as f:
        line = str(_zip) + " ,"
        for second_level_value in unique_second_level:
            search_tuple = _zip, second_level_value 
            line += str(x[search_tuple]*100)
            line += "%"
            line += ","
        line += "\n"
        f.write(line)
            
with open('2015_zip_DetailedFamilyType.csv', 'w') as f:
        line = "Zip" + ","
        for second_level_value in unique_second_level:
            line = line + str(second_level_value) + ","
        line += "\n"
        f.write(line)
        
groupby_df = sa2015.groupby('Zip').Detailed_Family_Type.value_counts('F')        


# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.Zip)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.Detailed_Family_Type)))
# print(unique_second_level)

zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for first_level_value in unique_first_level:
    for second_level_value in unique_second_level:
            search_tuple = first_level_value , second_level_value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('Zip')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.'
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')

# %%
# -- GENDER --- #

# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.Zip)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.Gender)))
# print(unique_second_level)

'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''

def write_df(x):
    for key,index in x.iteritems():
        _zip = key[0]
        break
    with open('2015_zip_Gender.csv', 'a') as f:
        line = str(_zip) + " ,"
        for second_level_value in unique_second_level:
            search_tuple = _zip, second_level_value 
            line += str(x[search_tuple]*100)
            line += "%"
            line += ","
        line += "\n"
        f.write(line)
            
with open('2015_zip_Gender.csv', 'w') as f:
        line = "Zip" + ","
        for second_level_value in unique_second_level:
            line = line + str(second_level_value) + ","
        line += "\n"
        f.write(line)
        
groupby_df = sa2015.groupby('Zip').Gender.value_counts('F')        

zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for first_level_value in unique_first_level:
    for second_level_value in unique_second_level:
            search_tuple = first_level_value , second_level_value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('Zip')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.'
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')

# %%
# --------------  RACE DESCRIPTION --------- #

# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.Zip)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.Race_Description)))
# print(unique_second_level)


'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''

def write_df(x):
    print(x)
    for key,index in x.iteritems():
        _zip = key[0]
        break
    with open('2015_zip_Race_Description.csv', 'a') as f:
        line = str(_zip) + " ,"
        for second_level_value in unique_second_level:
            search_tuple = _zip, second_level_value 
            line += str(x[search_tuple]*100)
            line += "%"
            line += ","
        line += "\n"
        f.write(line)
            
with open('2015_zip_Race_Description.csv', 'w') as f:
        line = "Zip" + ","
        for second_level_value in unique_second_level:
            line = line + str(second_level_value) + ","
        line += "\n"
        f.write(line)
        
groupby_df = sa2015.groupby('Zip').Race_Description.value_counts('F')        
print(groupby_df)


zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for first_level_value in unique_first_level:
    for second_level_value in unique_second_level:
            search_tuple = first_level_value , second_level_value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('Zip')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.'
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')
# Out:
# Zip    Race_Description
# 85003  White                                        0.882353
#        Black or African American                    0.117647
# 85004  Black or African American                    0.500000
#        White                                        0.500000
# 85006  Unknown or Not Entered                       0.388889
#        White                                        0.388889
#        Black or African American                    0.148148
#        American India or Alaska Native              0.074074
# 85007  White                                        0.458824
#        Black or African American                    0.317647
#        Unknown or Not Entered                       0.223529
# 85008  White                                        0.418301
#        Unknown or Not Entered                       0.281046
#        Black or African American                    0.241830
#        American India or Alaska Native              0.052288
# ...

# %%
# --------------  COUNTY --------- #

# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.Zip)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.County)))
# print(unique_second_level)


'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''

def write_df(x):
    print(x)
    for key,index in x.iteritems():
        _zip = key[0]
        break
    with open('2015_zip_County.csv', 'a') as f:
        line = str(_zip) + " ,"
        for second_level_value in unique_second_level:
            search_tuple = _zip, second_level_value 
            line += str(x[search_tuple]*100)
            line += "%"
            line += ","
        line += "\n"
        f.write(line)
            
with open('2015_zip_County.csv', 'w') as f:
        line = "Zip" + ","
        for second_level_value in unique_second_level:
            # Cleaning the county names!
            second_level_value = str(second_level_value)
            second_level_value = second_level_value.replace(","," ")
            line = line + str(second_level_value) + ","
        line += "\n"
        f.write(line)
        
groupby_df = sa2015.groupby('Zip').County.value_counts('F')        
print(groupby_df)


zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for first_level_value in unique_first_level:
    for second_level_value in unique_second_level:
            search_tuple = first_level_value , second_level_value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('Zip')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.'
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')
# Out:
# Zip    County
# 85003  Maricopa County         1.000000
# 85004  Maricopa County         1.000000
# 85006  Maricopa County         1.000000
# 85007  Maricopa County         1.000000
# 85008  Maricopa County         0.986928
#        Maricopa County, AZ     0.013072
# 85009  Maricopa County         0.992188
#        Multnomah County, OR    0.007812
# 85012  Maricopa County         1.000000
# 85013  Maricopa County         1.000000
# 85014  Maricopa County         0.912791
#        Coconino County         0.052326
#        Pinal County            0.023256
#        Maricopa County, AZ     0.011628
# 85015  Maricopa County         1.000000
# 85016  Maricopa County         1.000000
# 85017  Maricopa County         1.000000
# 85018  Maricopa County         1.000000
# 85019  Maricopa County         1.000000
# 85020  Maricopa County         1.000000
# 85021  Maricopa County         1.000000
# 85022  Maricopa County         1.000000
# 85023  Maricopa County         1.000000
# ...

# %%
# --------------  ETHNICITY --------- #

# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.Zip)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.Ethnicity)))
# print(unique_second_level)


'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''

def write_df(x):
    print(x)
    for key,index in x.iteritems():
        _zip = key[0]
        break
    with open('2015_zip_Ethnicity.csv', 'a') as f:
        line = str(_zip) + " ,"
        for second_level_value in unique_second_level:
            search_tuple = _zip, second_level_value 
            line += str(x[search_tuple]*100)
            line += "%"
            line += ","
        line += "\n"
        f.write(line)
            
with open('2015_zip_Ethnicity.csv', 'w') as f:
        line = "Zip" + ","
        for second_level_value in unique_second_level:
            second_level_value = str(second_level_value)
            second_level_value = second_level_value.replace(","," ")
            line = line + str(second_level_value) + ","
        line += "\n"
        f.write(line)
        
groupby_df = sa2015.groupby('Zip').Ethnicity.value_counts('F')        
print(groupby_df)


zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for first_level_value in unique_first_level:
    for second_level_value in unique_second_level:
            search_tuple = first_level_value , second_level_value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('Zip')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.'
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')
# Out:
# Zip    Ethnicity
# 85003  Hispanic        0.705882
#        Non-Hispanic    0.294118
# 85004  Hispanic        0.500000
#        Non-Hispanic    0.500000
# 85006  Hispanic        0.555556
#        Non-Hispanic    0.444444
# 85007  Hispanic        0.517647
#        Non-Hispanic    0.482353
# 85008  Non-Hispanic    0.562092
#        Hispanic        0.437908
# 85009  Hispanic        0.695312
#        Non-Hispanic    0.304688
# 85012  Hispanic        0.666667
#        Non-Hispanic    0.333333
# 85013  Non-Hispanic    0.863636
#        Hispanic        0.136364
# 85014  Non-Hispanic    0.662791
#        Hispanic        0.337209
# 85015  Non-Hispanic    0.678571
#        Hispanic        0.321429
# 85016  Non-Hispanic    0.585366
#        Hispanic        0.414634
# 85017  Hispanic        0.647887
#        Non-Hispanic    0.352113
# 85018  Non-Hispanic    0.567568
#        Hispanic        0.432432
# 85019  Hispanic        0.779221
#        Non-Hispanic    0.220779
# ...

# %%
### -------------------------------------------------------------------------------
## Below code is for : First level -> Gender


'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''
def write_df(x):
    with open('2015_Zip_Gender.csv', 'a') as f: 
        x.to_csv(f)
with open('2015_Zip_Gender.csv', 'w') as f: 
        f.write("Zip , Gender , Fraction \n")
        
        
groupby_df = sa2015.groupby('Zip').Gender.value_counts('F')

# Get unique zip codes [First Level]
unique_zip = list(set(list(sa2015.Zip)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_columns = list(set(list(sa2015.Gender)))
print(unique_columns)

zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for zip in unique_zip:
    for value in unique_columns:
            search_tuple = zip , value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('Zip')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')


'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''

def write_df(x):
    with open('2015_County_Gender.csv', 'a') as f: 
        x.to_csv(f)
with open('2015_County_Gender.csv', 'w') as f: 
        f.write("County , Gender , Fraction \n")
        
groupby_df = sa2015.groupby('Zip').County.value_counts('F')        
# groupby_df = sa2015.groupby('County').Gender.value_counts('F')

# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.County)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.Gender)))
print(unique_second_level)

zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for first_level_value in unique_first_level:
    for second_level_value in unique_second_level:
            search_tuple = first_level_value , second_level_value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('County')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')

'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''

def write_df(x):
    with open('2015_Race_Gender.csv', 'a') as f: 
        x.to_csv(f)
with open('2015_Race_Gender.csv', 'w') as f: 
        f.write("Race , Gender , Fraction \n")
        
        
groupby_df = sa2015.groupby('Race_Description').Gender.value_counts('F')

# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.Race_Description)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.Gender)))
print(unique_second_level)

zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for first_level_value in unique_first_level:
    for second_level_value in unique_second_level:
            search_tuple = first_level_value , second_level_value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('Race_Description')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')
'''
Append dataframe into file
@Param : Pandas.Dataframe : Dataframe which is to be appended in the file
'''

def write_df(x):
    with open('2015_Ethnicity_Gender.csv', 'a') as f: 
        x.to_csv(f)
with open('2015_Ethnicity_Gender.csv', 'w') as f: 
        f.write("Race , Gender , Fraction \n")
        
        
groupby_df = sa2015.groupby('Ethnicity').Gender.value_counts('F')

# Get unique zip codes [First Level]
unique_first_level = list(set(list(sa2015.Ethnicity)))
# print(unique_zip)
# Get unique columns [Second Level]
unique_second_level = list(set(list(sa2015.Gender)))
print(unique_second_level)

zip_code = ""

# Check if the zip (First Level) -> Gender(Second Level) entry is present or not in the groupby  object
# If not, append the entry as zero in the dataframe
for first_level_value in unique_first_level:
    for second_level_value in unique_second_level:
            search_tuple = first_level_value , second_level_value
            try:
#                 print(new_df_gender.loc[search_tuple])
                temp = groupby_df.loc[search_tuple]
            except:
                # If not in groupby object, it comes here!
                groupby_df[search_tuple] = 0
#                 print(groupby_df.loc[search_tuple])
#                 print(search_tuple,"Not there!")
#             print(search_tuple)
#             new_df_gender[search_tuple] = groupby_df.loc[search_tuple]
#             print(new_df_gender.loc[search_tuple])

# As Modified data frame will not have all the group based on the zip (First Level) 
# Grouping again based on the Zip 
groupby_df = groupby_df.groupby('Ethnicity')

# for key,item in groupby_df:
#      print (groupby_df.get_group(key), "\n\n")

# Writing Final groupby object onto file.
# Passing each data frame into function  
temp_df = groupby_df.apply(lambda x: write_df(x))

    
# a
# for index,row in a:
#     print(index,row)
# b = sa2015.groupby('Zip').Gender.count()
# c = a/b
# c
# a
#count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
#c.to_csv('Gender.csv')


## Code for First level -> Gender completes!
###----------------------------------------------------------------
# Out:
#   File "<ipython-input-45-86a4001d59a6>", line 12
#     groupby_df = sa2015.groupby('Zip')..value_counts('F')
#                                        ^
# SyntaxError: invalid syntax

# %%
# Out:
# ['M', 'F']

# %%
sa2015.Race_Description.value_counts()

# %%
sa2015.Ethnicity.value_counts()

# %%
sa2015.State.unique()

# %%
sa2015.describe().transpose()

# %%
#sa2015.groupby('Zip').describe().to_csv('sa2015_Zip.csv')
sa2015.groupby('Zip').describe()

# %%
sa2016.groupby('Zip').describe().to_csv('sa2016_Zip.csv')
#sa2016.groupby('Zip').describe()

# %%
# Checking missing values
print sa2015.isnull().any()

# %%
# Checking missing values
print sa2016.isnull().any()

# %%
# Checking missing values
print sa2017.isnull().any()
